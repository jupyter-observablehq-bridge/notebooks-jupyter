# %%
# %load_ext autoreload
# %autoreload 2

# %%
import zlib
from IPython import display
from base64 import b64decode


from job_client_graphql import Client

# %% [markdown]
# ## Prerequisite
# + Launch JOB server - see [documentation](TBD) section **5-Examples**

# %%
pages = {
    'upload-file': 'https://observablehq.com/@oscar6echo/job-example-upload-file',
}

# %%
s = Client(server_url='http://localhost:4001/graphql',
           default_channel='channel-1',
           password='mysecret',
           pages=pages,         
           debug=False)
print(s.build_url('upload-file'))
s.show_btn_page('upload-file')
# Out:
# https://observablehq.com/@oscar6echo/job-example-upload-file?host=localhost&port=4001&path=/graphql&ssl=False&channel=channel-1
#         <div style="display: flex; align-items: center">
#             <div style="
#         margin-right: 20px;;
#         ">Page <span style="color:red;">UPLOAD-FILE</span></div>
#             <button style="
#         background-color:light-grey;
#         width: 200px;
#
#         margin-right: 20px;;
#         " onclick="window.open('https://observablehq.com/@oscar6echo/job-example-upload-file?host=localhost&port=4001&path=/graphql&ssl=False&channel=channel-1', '_blank'); return false;">Open in new tab</button>
#             <button style="
#         background-color:light-grey;
#         width: 200px;
#         " onclick="
#             const el = document.createElement('textarea');
#             el.value = `https://observablehq.com/@oscar6echo/job-example-upload-file?host=localhost&port=4001&path=/graphql&ssl=False&channel=channel-1`;
# ...

# %% [markdown]
# ## Read

# %%
d1 = s.read('file-img')

# %%
display.Image(b64decode(d1))

# %%
d2 = s.read('file-img-compressed')
d2_bis = zlib.decompress(b64decode(d2))

# %%
display.Image(d2_bis)

# %% [markdown]
# ## Store

# %%
s.store['channel-1'].keys()
# Out:
# dict_keys(['file-img', 'file-img-compressed'])
